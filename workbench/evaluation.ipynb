# %%
import glob
from collections import defaultdict
import time
import json
from google.cloud import storage
from google.cloud import aiplatform_v1

# %%
from google.cloud import storage
import json

client = storage.Client()
bucket = client.bucket("axmt_equipment_profile")
blob = bucket.blob("siglip_vectors/local_image_vectors.json")

content = blob.download_as_text()

original_path_train = {}
label_class = {}

for l in content.splitlines():
    p = json.loads(l)
    id = p['id']
    original_path_train[id] = p['original_path']
    label_class[id] = p['label_class']

# %%
first_key, first_value = next(iter(label_class.items()))
print(first_key, ':', first_value)
# Out:
# AI1_32920fc6-8615-453b-a586-1901fefcc063 : AI1

# %%
INDEX_ENDPOINT="projects/629242692180/locations/asia-southeast1/indexEndpoints/43567048738996224"
DEPLOYED_INDEX_ID="equipment_profile_1765769745213"
TEST_DATA_PATH="gs://axmt_equipment_profile/siglip_vectors_test"
API_ENDPOINT="1148065613.asia-southeast1-629242692180.vdb.vertexai.goog"

client_options = {
  "api_endpoint": API_ENDPOINT
}
vector_search_client = aiplatform_v1.MatchServiceClient(
  client_options=client_options,
)

# %%
def evaluate_equipment_test_dataset_from_embeddings(test_data_path=TEST_DATA_PATH,
                                     index_endpoint=INDEX_ENDPOINT, 
                                     deployed_index_id=DEPLOYED_INDEX_ID, 
                                     num_neighbors=5,
                                     max_images_per_class=None):
    # Initialize results tracking
    results = {
        'total_queries': 0,
        'correct_predictions': 0,
        'class_results': defaultdict(lambda: {'total': 0, 'correct': 0, 'predictions': []}),
        'detailed_results': []
    }
    
    # Load test embeddings from GCS
    test_embeddings = []
    
    print(f"Loading test embeddings from GCS path: {test_data_path}")
    
    # Parse GCS path
    gcs_path = test_data_path.replace('gs://', '')
    bucket_name = gcs_path.split('/')[0]
    blob_prefix = '/'.join(gcs_path.split('/')[1:]) if len(gcs_path.split('/')) > 1 else ''
    
    # Initialize GCS client
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    
    # List all JSON files in the GCS path
    blobs = bucket.list_blobs(prefix=blob_prefix)
    
    for blob in blobs:
        if blob.name.endswith('.json'):
            print(f"Processing GCS file: {blob.name}")
            
            try:
                # Download and parse JSON content
                content = blob.download_as_text()
                
                for line in content.splitlines():
                    if line.strip():
                        try:
                            embedding_data = json.loads(line)
                            
                            # Extract relevant information
                            original_path = embedding_data.get('original_path', '')
                            label_class_val = embedding_data.get('label_class', '')
                            embedding_vector = embedding_data.get('embedding', [])
                            data_id = embedding_data.get('id', '')
                            
                            # Filter for test images (assuming they contain 'test' in path)
                            if 'test' in original_path.lower() and embedding_vector:
                                test_embeddings.append({
                                    'path': original_path,
                                    'class': label_class_val,
                                    'id': data_id,
                                    'embedding': embedding_vector
                                })
                                
                        except json.JSONDecodeError as e:
                            print(f"Error parsing JSON line: {e}")
                            continue
                            
            except Exception as e:
                print(f"Error processing GCS blob {blob.name}: {e}")
                continue
                
    if not test_embeddings:
        raise ValueError("No test embeddings found. Please check your GCS path contains test data.")
    
    print(f"Found {len(test_embeddings)} test embeddings from GCS")
    
    # Group by class for max_images_per_class filtering
    embeddings_by_class = defaultdict(list)
    for emb_data in test_embeddings:
        embeddings_by_class[emb_data['class']].append(emb_data)
    
    # Apply max_images_per_class limit if specified
    if max_images_per_class:
        filtered_embeddings = []
        for class_name, class_embeddings in embeddings_by_class.items():
            filtered_embeddings.extend(class_embeddings[:max_images_per_class])
        test_embeddings = filtered_embeddings
        
    # Get unique classes
    equipment_classes = list(set([emb['class'] for emb in test_embeddings]))
    
    print(f"Found {len(equipment_classes)} equipment classes: {sorted(equipment_classes)}")
    print(f"Total test embeddings: {len(test_embeddings)}")
    print(f"Starting evaluation with {num_neighbors} neighbors per query...\n")
    
    for emb_data in test_embeddings:
        original_path = emb_data['path']
        true_class = emb_data['class']
        query_embedding = emb_data['embedding']
        
        try:
            # Create vector search request using pre-computed embedding
            datapoint = aiplatform_v1.IndexDatapoint(
                feature_vector=query_embedding
            )

            query = aiplatform_v1.FindNeighborsRequest.Query(
                datapoint=datapoint,
                neighbor_count=num_neighbors
            )

            request = aiplatform_v1.FindNeighborsRequest(
                index_endpoint=index_endpoint,
                deployed_index_id=deployed_index_id,
                queries=[query],
                return_full_datapoint=False,
            )

            # Execute the request
            response = vector_search_client.find_neighbors(request)
            
            if response and response.nearest_neighbors:
                # Get the top prediction
                neighbors = response.nearest_neighbors[0].neighbors
                
                # Extract predicted classes from neighbors
                predicted_classes = []
                neighbor_details = []
                
                for neighbor in neighbors:
                    neighbor_id = neighbor.datapoint.datapoint_id
                    distance = neighbor.distance
                    
                    # Get the predicted class from the neighbor ID
                    if neighbor_id in label_class:
                        pred_class = label_class[neighbor_id]
                        predicted_classes.append(pred_class)
                        neighbor_details.append({
                            'id': neighbor_id,
                            'predicted_class': pred_class,
                            'distance': distance,
                            'original_path': original_path_train[neighbor_id]
                        })

                # Determine if prediction is correct (top-1 and top-k accuracy)
                top1_correct = predicted_classes[0] == true_class if predicted_classes else False
                topk_correct = true_class in predicted_classes[:num_neighbors] if predicted_classes else False

                # Update results
                results['total_queries'] += 1
                results['class_results'][true_class]['total'] += 1

                if top1_correct:
                    results['correct_predictions'] += 1
                    results['class_results'][true_class]['correct'] += 1
                    
                # Store detailed results
                result_detail = {
                    'query_image': original_path,
                    'true_class': true_class,
                    'predicted_classes': predicted_classes,
                    'top1_correct': top1_correct,
                    'topk_correct': topk_correct,
                    'neighbors': neighbor_details
                }
                results['detailed_results'].append(result_detail)
                results['class_results'][true_class]['predictions'].append(result_detail)
                
                # Print progress
                if results['total_queries'] % 10 == 0:
                    current_accuracy = (results['correct_predictions'] / results['total_queries']) * 100
                    print(f"Processed {results['total_queries']} embeddings, Current accuracy: {current_accuracy:.2f}%")
            
            else:
                print(f"No response for embedding: {original_path}")
                
            # Small delay to avoid overwhelming the API
            time.sleep(0.1)
            
        except Exception as e:
            print(f"Error processing embedding {original_path}: {e}")
            continue
            
    # Calculate final metrics
    overall_accuracy = (results['correct_predictions'] / results['total_queries']) * 100 if results['total_queries'] > 0 else 0
    
    # Calculate per-class accuracy
    class_accuracies = {}
    for class_name, class_data in results['class_results'].items():
        if class_data['total'] > 0:
            class_accuracies[class_name] = (class_data['correct'] / class_data['total']) * 100
        else:
            class_accuracies[class_name] = 0
    
    # Add summary to results
    results['summary'] = {
        'overall_accuracy': overall_accuracy,
        'class_accuracies': class_accuracies,
        'total_classes': len(equipment_classes),
        'avg_class_accuracy': sum(class_accuracies.values()) / len(class_accuracies) if class_accuracies else 0
    }
            
    return results

# %%
print("Running evaluation using pre-computed embeddings from GCS ...")
results = evaluate_equipment_test_dataset_from_embeddings(
    test_data_path=TEST_DATA_PATH,  # GCS path with embedding JSON files
    index_endpoint=INDEX_ENDPOINT,
    deployed_index_id=DEPLOYED_INDEX_ID,
    num_neighbors=5,
    max_images_per_class=None
)
# Out:
# Running evaluation using pre-computed embeddings from GCS ...
# Loading test embeddings from GCS path: gs://axmt_equipment_profile/siglip_vectors_test
# Processing GCS file: siglip_vectors_test/local_image_vectors_test.json
# Found 537 test embeddings from GCS
# Found 21 equipment classes: ['AI1', 'AI10', 'AI11', 'AI12', 'AI13', 'AI14', 'AI15', 'AI16', 'AI17', 'AI18', 'AI19', 'AI2', 'AI21', 'AI22', 'AI3', 'AI4', 'AI5', 'AI6', 'AI7', 'AI8', 'AI9']
# Total test embeddings: 537
# Starting evaluation with 5 neighbors per query...
#
# Processed 10 embeddings, Current accuracy: 100.00%
# Processed 20 embeddings, Current accuracy: 100.00%
# Processed 30 embeddings, Current accuracy: 100.00%
# Processed 40 embeddings, Current accuracy: 100.00%
# Processed 50 embeddings, Current accuracy: 100.00%
# Processed 60 embeddings, Current accuracy: 100.00%
# Processed 70 embeddings, Current accuracy: 100.00%
# Processed 80 embeddings, Current accuracy: 100.00%
# Processed 90 embeddings, Current accuracy: 100.00%
# Processed 100 embeddings, Current accuracy: 100.00%
# Processed 110 embeddings, Current accuracy: 100.00%
# Processed 120 embeddings, Current accuracy: 100.00%
# Processed 130 embeddings, Current accuracy: 100.00%
# Processed 140 embeddings, Current accuracy: 100.00%
# Processed 150 embeddings, Current accuracy: 100.00%
# Processed 160 embeddings, Current accuracy: 100.00%
# Processed 170 embeddings, Current accuracy: 100.00%
# Processed 180 embeddings, Current accuracy: 100.00%
# Processed 190 embeddings, Current accuracy: 100.00%
# Processed 200 embeddings, Current accuracy: 100.00%
# Processed 210 embeddings, Current accuracy: 100.00%
# Processed 220 embeddings, Current accuracy: 100.00%
# Processed 230 embeddings, Current accuracy: 100.00%
# Processed 240 embeddings, Current accuracy: 100.00%
# Processed 250 embeddings, Current accuracy: 100.00%
# Processed 260 embeddings, Current accuracy: 100.00%
# Processed 270 embeddings, Current accuracy: 100.00%
# Processed 280 embeddings, Current accuracy: 100.00%
# Processed 290 embeddings, Current accuracy: 100.00%
# Processed 300 embeddings, Current accuracy: 100.00%
# Processed 310 embeddings, Current accuracy: 100.00%
# Processed 320 embeddings, Current accuracy: 100.00%
# Processed 330 embeddings, Current accuracy: 100.00%
# Processed 340 embeddings, Current accuracy: 100.00%
# Processed 350 embeddings, Current accuracy: 100.00%
# Processed 360 embeddings, Current accuracy: 100.00%
# Processed 370 embeddings, Current accuracy: 100.00%
# Processed 380 embeddings, Current accuracy: 100.00%
# Processed 390 embeddings, Current accuracy: 100.00%
# Processed 400 embeddings, Current accuracy: 100.00%
# Processed 410 embeddings, Current accuracy: 100.00%
# Processed 420 embeddings, Current accuracy: 100.00%
# Processed 430 embeddings, Current accuracy: 100.00%
# Processed 440 embeddings, Current accuracy: 100.00%
# Processed 450 embeddings, Current accuracy: 100.00%
# Processed 460 embeddings, Current accuracy: 100.00%
# Processed 470 embeddings, Current accuracy: 100.00%
# Processed 480 embeddings, Current accuracy: 100.00%
# Processed 490 embeddings, Current accuracy: 100.00%
# Processed 500 embeddings, Current accuracy: 100.00%
# Processed 510 embeddings, Current accuracy: 100.00%
# Processed 520 embeddings, Current accuracy: 100.00%
# Processed 530 embeddings, Current accuracy: 100.00%

# %%
def display_evaluation_results(results):
    """
    Display comprehensive evaluation results in a formatted way.
    
    Args:
        results (dict): Evaluation results containing accuracy metrics and detailed results
    """
    print("=" * 80)
    print("EQUIPMENT PROFILE VECTOR SEARCH - EVALUATION RESULTS")
    print("=" * 80)
    
    # Overall metrics
    summary = results.get('summary', {})
    print(f"\n📊 OVERALL PERFORMANCE:")
    print(f"   Total Queries: {results.get('total_queries', 0)}")
    print(f"   Correct Predictions: {results.get('correct_predictions', 0)}")
    print(f"   Overall Accuracy: {summary.get('overall_accuracy', 0):.2f}%")
    print(f"   Average Class Accuracy: {summary.get('avg_class_accuracy', 0):.2f}%")
    print(f"   Total Classes: {summary.get('total_classes', 0)}")
    
    # Per-class accuracy
    print(f"\n🎯 PER-CLASS ACCURACY:")
    class_accuracies = summary.get('class_accuracies', {})
    class_results = results.get('class_results', {})
    
    if class_accuracies:
        # Sort classes by accuracy (descending)
        sorted_classes = sorted(class_accuracies.items(), key=lambda x: x[1], reverse=True)
        
        print(f"{'Class':<8} {'Accuracy':<10} {'Correct':<8} {'Total':<8}")
        print("-" * 40)
        
        for class_name, accuracy in sorted_classes:
            class_data = class_results.get(class_name, {})
            correct = class_data.get('correct', 0)
            total = class_data.get('total', 0)
            print(f"{class_name:<8} {accuracy:>7.2f}%  {correct:>6} / {total:<6}")
    
    # Performance insights
#     print(f"\n💡 INSIGHTS:")
#     if class_accuracies:
#         best_class = max(class_accuracies.items(), key=lambda x: x[1])
#         worst_class = min(class_accuracies.items(), key=lambda x: x[1])
        
#         print(f"   Best Performing Class: {best_class[0]} ({best_class[1]:.2f}%)")
#         print(f"   Worst Performing Class: {worst_class[0]} ({worst_class[1]:.2f}%)")
        
#         # Calculate performance distribution
#         high_perf = sum(1 for acc in class_accuracies.values() if acc >= 90)
#         medium_perf = sum(1 for acc in class_accuracies.values() if 70 <= acc < 90)
#         low_perf = sum(1 for acc in class_accuracies.values() if acc < 70)
        
#         print(f"   High Performance (≥90%): {high_perf} classes")
#         print(f"   Medium Performance (70-89%): {medium_perf} classes")
#         print(f"   Low Performance (<70%): {low_perf} classes")
    
    print("\n" + "=" * 80)

# %%
display_evaluation_results(results)
# Out:
# ================================================================================
# EQUIPMENT PROFILE VECTOR SEARCH - EVALUATION RESULTS
# ================================================================================
#
# 📊 OVERALL PERFORMANCE:
#    Total Queries: 537
#    Correct Predictions: 537
#    Overall Accuracy: 100.00%
#    Average Class Accuracy: 100.00%
#    Total Classes: 21
#
# 🎯 PER-CLASS ACCURACY:
# Class    Accuracy   Correct  Total
# ----------------------------------------
# AI1       100.00%      26 / 26
# AI2       100.00%      42 / 42
# AI3       100.00%      26 / 26
# AI4       100.00%      33 / 33
# AI5       100.00%      27 / 27
# AI6       100.00%      21 / 21
# AI7       100.00%      23 / 23
# AI8       100.00%      22 / 22
# AI9       100.00%      33 / 33
# AI10      100.00%      28 / 28
# AI11      100.00%      16 / 16
# AI12      100.00%      19 / 19
# AI13      100.00%      21 / 21
# AI14      100.00%      20 / 20
# AI15      100.00%      33 / 33
# AI16      100.00%      22 / 22
# AI17      100.00%      21 / 21
# AI18      100.00%      26 / 26
# AI19      100.00%      40 / 40
# AI21      100.00%      20 / 20
# AI22      100.00%      18 / 18
#
# ================================================================================

# %%
results['class_results']['AI1']
# Out:
# {'total': 26,
#  'correct': 26,
#  'predictions': [{'query_image': 'dataset/equipment_test/AI1/20251112_112314(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_589edcf8-e820-45c1-a13b-787315e93eb5',
#      'predicted_class': 'AI1',
#      'distance': 0.9917260408401489,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112314.jpg'},
#     {'id': 'AI1_e133f458-2dd0-4efa-9362-3451bc42000e',
#      'predicted_class': 'AI1',
#      'distance': 0.9877064228057861,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315.jpg'},
#     {'id': 'AI1_3e0d6fae-5c10-4076-942c-516a92dbb08a',
#      'predicted_class': 'AI1',
#      'distance': 0.9814499616622925,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(0).jpg'},
#     {'id': 'AI1_5833b87b-3029-42b5-a80d-ca555a9f5078',
#      'predicted_class': 'AI1',
#      'distance': 0.9752538204193115,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(3).jpg'},
#     {'id': 'AI1_32920fc6-8615-453b-a586-1901fefcc063',
#      'predicted_class': 'AI1',
#      'distance': 0.9749666452407837,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(4).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112432.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_f2d7b230-5c4a-414c-bdbd-7785073390ee',
#      'predicted_class': 'AI1',
#      'distance': 0.9868144989013672,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112432(0).jpg'},
#     {'id': 'AI1_8403bedb-60e8-42b8-a4b6-8e2cfbf2db3a',
#      'predicted_class': 'AI1',
#      'distance': 0.9769537448883057,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112433.jpg'},
#     {'id': 'AI1_8caf9f61-bd87-42ec-a250-6a176a8d1091',
#      'predicted_class': 'AI1',
#      'distance': 0.9671614170074463,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112431(0).jpg'},
#     {'id': 'AI1_6c16c962-a8b6-4e0d-bf6c-5f689d1b8457',
#      'predicted_class': 'AI1',
#      'distance': 0.9662296175956726,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112431.jpg'},
#     {'id': 'AI1_a7381f8b-836f-4344-a6fa-e70780529707',
#      'predicted_class': 'AI1',
#      'distance': 0.9654623866081238,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112433(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112421(2).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_070fa949-3c19-44df-a309-1e613ad3ff1b',
#      'predicted_class': 'AI1',
#      'distance': 0.9727920293807983,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(2).jpg'},
#     {'id': 'AI1_2c0cdd1a-e7d0-4321-8ca5-ab683346b327',
#      'predicted_class': 'AI1',
#      'distance': 0.972220778465271,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(1).jpg'},
#     {'id': 'AI1_719701c5-533a-47ae-89ad-93229d6f7396',
#      'predicted_class': 'AI1',
#      'distance': 0.9686400294303894,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(3).jpg'},
#     {'id': 'AI1_de9c2bb9-425f-4b03-a98d-ac191c7ccd05',
#      'predicted_class': 'AI1',
#      'distance': 0.9678460359573364,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(0).jpg'},
#     {'id': 'AI1_4a48899a-9ece-4c59-b8fd-4175b273d037',
#      'predicted_class': 'AI1',
#      'distance': 0.9668444395065308,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112421.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112330(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_61fbdc1a-4b71-4504-bc9c-c63699232699',
#      'predicted_class': 'AI1',
#      'distance': 0.988152801990509,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112330.jpg'},
#     {'id': 'AI1_02a309ea-8e86-47e8-9903-30fbc429ad6a',
#      'predicted_class': 'AI1',
#      'distance': 0.9687460660934448,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112330(1).jpg'},
#     {'id': 'AI1_72a6f258-29ae-4bde-bd4a-cd41eeee045f',
#      'predicted_class': 'AI1',
#      'distance': 0.9539222121238708,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331.jpg'},
#     {'id': 'AI1_58ac5f0f-b076-47bb-9c68-b001f7d2c6f8',
#      'predicted_class': 'AI1',
#      'distance': 0.935227632522583,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(0).jpg'},
#     {'id': 'AI1_48536121-e4b0-40ba-90e9-6e7e6feda8f1',
#      'predicted_class': 'AI1',
#      'distance': 0.9303005933761597,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(1).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112316(1).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_8d7cea8b-49b3-42fc-a676-a5b46cd07e4c',
#      'predicted_class': 'AI1',
#      'distance': 0.9842836856842041,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112316(0).jpg'},
#     {'id': 'AI1_5833b87b-3029-42b5-a80d-ca555a9f5078',
#      'predicted_class': 'AI1',
#      'distance': 0.9714940786361694,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(3).jpg'},
#     {'id': 'AI1_32920fc6-8615-453b-a586-1901fefcc063',
#      'predicted_class': 'AI1',
#      'distance': 0.9708001017570496,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(4).jpg'},
#     {'id': 'AI1_3e0d6fae-5c10-4076-942c-516a92dbb08a',
#      'predicted_class': 'AI1',
#      'distance': 0.9689916372299194,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(0).jpg'},
#     {'id': 'AI1_d5041478-8078-4761-b130-315099ffe5c7',
#      'predicted_class': 'AI1',
#      'distance': 0.9680773615837097,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112316.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112418.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_bcdd9de5-77f4-480e-8f39-7cd89696f3dc',
#      'predicted_class': 'AI1',
#      'distance': 0.9849897623062134,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(0).jpg'},
#     {'id': 'AI1_57b413ea-4ded-44f5-bdf7-ec079491b167',
#      'predicted_class': 'AI1',
#      'distance': 0.9842309951782227,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112417.jpg'},
#     {'id': 'AI1_57a082f0-c414-4081-8243-ab0d75f36986',
#      'predicted_class': 'AI1',
#      'distance': 0.9772371649742126,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(1).jpg'},
#     {'id': 'AI1_40b23d3f-0291-4c13-903a-4d6a54f9faf7',
#      'predicted_class': 'AI1',
#      'distance': 0.9670591950416565,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(2).jpg'},
#     {'id': 'AI1_c6106a5c-6e2e-46b7-a014-df17edf00b2a',
#      'predicted_class': 'AI1',
#      'distance': 0.9344828128814697,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112342(4).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112304(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_cb20c678-49a0-45c1-93ad-fa21d79e92df',
#      'predicted_class': 'AI1',
#      'distance': 0.9894536733627319,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112303.jpg'},
#     {'id': 'AI1_abd62e79-f5ca-42ba-bb6c-88e5fa01bf8d',
#      'predicted_class': 'AI1',
#      'distance': 0.9830556511878967,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112304.jpg'},
#     {'id': 'AI1_64609ce6-d264-427b-8b32-29f48edb2f0f',
#      'predicted_class': 'AI1',
#      'distance': 0.9823447465896606,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112304(1).jpg'},
#     {'id': 'AI1_e132b215-de11-4ba0-99ba-0917a8bca509',
#      'predicted_class': 'AI1',
#      'distance': 0.9713499546051025,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112305(2).jpg'},
#     {'id': 'AI1_042dbeb8-684b-47b0-b32f-4954c5145427',
#      'predicted_class': 'AI1',
#      'distance': 0.964993953704834,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112305.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112419(2).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_a1487fbc-987f-4b22-80aa-7d8d3fc6f526',
#      'predicted_class': 'AI1',
#      'distance': 0.9770548343658447,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420.jpg'},
#     {'id': 'AI1_40b23d3f-0291-4c13-903a-4d6a54f9faf7',
#      'predicted_class': 'AI1',
#      'distance': 0.9591790437698364,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(2).jpg'},
#     {'id': 'AI1_ffad92e0-2bd6-4ae2-9079-d1f588d2e88d',
#      'predicted_class': 'AI1',
#      'distance': 0.9582494497299194,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112419(3).jpg'},
#     {'id': 'AI1_0a4bfafc-6680-4a5f-b8c4-5e1edfc98aa3',
#      'predicted_class': 'AI1',
#      'distance': 0.9566932916641235,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112423(2).jpg'},
#     {'id': 'AI1_87ec4b7f-8562-4488-96e2-ec5bec06f574',
#      'predicted_class': 'AI1',
#      'distance': 0.9560232162475586,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(1).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112423.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_c6a5a19c-9fbb-4319-8d13-91d2ee65b6a3',
#      'predicted_class': 'AI1',
#      'distance': 0.9833522439002991,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(3).jpg'},
#     {'id': 'AI1_4e6e0746-d249-4e09-8e1f-c9343720cdf0',
#      'predicted_class': 'AI1',
#      'distance': 0.9774010181427002,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112423(0).jpg'},
#     {'id': 'AI1_070fa949-3c19-44df-a309-1e613ad3ff1b',
#      'predicted_class': 'AI1',
#      'distance': 0.9656058549880981,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(2).jpg'},
#     {'id': 'AI1_4a48899a-9ece-4c59-b8fd-4175b273d037',
#      'predicted_class': 'AI1',
#      'distance': 0.9634271264076233,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112421.jpg'},
#     {'id': 'AI1_2c0cdd1a-e7d0-4321-8ca5-ab683346b327',
#      'predicted_class': 'AI1',
#      'distance': 0.962838888168335,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(1).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112351.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_68a7ae66-713a-4b47-a444-52dffc52cfb9',
#      'predicted_class': 'AI1',
#      'distance': 0.97011399269104,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112351(0).jpg'},
#     {'id': 'AI1_2ca89edc-a440-4cfa-8bbe-454c66027ff3',
#      'predicted_class': 'AI1',
#      'distance': 0.9656888246536255,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112355.jpg'},
#     {'id': 'AI1_1c127333-aff0-40b3-9388-dc8cc6e87750',
#      'predicted_class': 'AI1',
#      'distance': 0.9593921303749084,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112356.jpg'},
#     {'id': 'AI1_cff315aa-fa38-48e1-b819-59b17a43f4f1',
#      'predicted_class': 'AI1',
#      'distance': 0.9581935405731201,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112350(1).jpg'},
#     {'id': 'AI1_ebe43d3a-6fd1-466b-aef8-2eaf6ea700d7',
#      'predicted_class': 'AI1',
#      'distance': 0.9491860866546631,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112356(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112332(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_79768711-8000-4081-841a-2fd9bd658da0',
#      'predicted_class': 'AI1',
#      'distance': 0.9706869125366211,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112332(1).jpg'},
#     {'id': 'AI1_832f85b9-0a0f-4dfe-a9d3-d35c9a1bb938',
#      'predicted_class': 'AI1',
#      'distance': 0.9623798131942749,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112332.jpg'},
#     {'id': 'AI1_2e4e09c5-41b9-47eb-913b-fd9e8eaf7ae5',
#      'predicted_class': 'AI1',
#      'distance': 0.9475566148757935,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(2).jpg'},
#     {'id': 'AI1_81db9ca2-39e1-459a-8a71-d3fb42c0a78c',
#      'predicted_class': 'AI1',
#      'distance': 0.9446766376495361,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112333(0).jpg'},
#     {'id': 'AI1_7827f991-bd2e-4e12-b86c-6ebf5e7776ce',
#      'predicted_class': 'AI1',
#      'distance': 0.9410291314125061,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112335.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112306(1).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_63e76bba-7536-48a2-aafc-6cfb3467dc71',
#      'predicted_class': 'AI1',
#      'distance': 0.9811383485794067,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112306(0).jpg'},
#     {'id': 'AI1_2ece8e6f-83c4-47a6-9c4e-3d05ffa7d675',
#      'predicted_class': 'AI1',
#      'distance': 0.9788619875907898,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112306.jpg'},
#     {'id': 'AI1_a067368f-56cb-4018-b860-0149a10b88f6',
#      'predicted_class': 'AI1',
#      'distance': 0.971045732498169,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112305(4).jpg'},
#     {'id': 'AI1_f791f110-e188-481a-87ac-034d6ab624af',
#      'predicted_class': 'AI1',
#      'distance': 0.9676385521888733,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112305(3).jpg'},
#     {'id': 'AI1_5833b87b-3029-42b5-a80d-ca555a9f5078',
#      'predicted_class': 'AI1',
#      'distance': 0.9584019780158997,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112315(3).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112432(1).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_8403bedb-60e8-42b8-a4b6-8e2cfbf2db3a',
#      'predicted_class': 'AI1',
#      'distance': 0.9830996990203857,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112433.jpg'},
#     {'id': 'AI1_f2d7b230-5c4a-414c-bdbd-7785073390ee',
#      'predicted_class': 'AI1',
#      'distance': 0.9826506972312927,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112432(0).jpg'},
#     {'id': 'AI1_a7381f8b-836f-4344-a6fa-e70780529707',
#      'predicted_class': 'AI1',
#      'distance': 0.9691228866577148,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112433(0).jpg'},
#     {'id': 'AI1_6c16c962-a8b6-4e0d-bf6c-5f689d1b8457',
#      'predicted_class': 'AI1',
#      'distance': 0.9630850553512573,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112431.jpg'},
#     {'id': 'AI1_8caf9f61-bd87-42ec-a250-6a176a8d1091',
#      'predicted_class': 'AI1',
#      'distance': 0.9630060195922852,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112431(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112441(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_e96888b8-3ac6-4400-a584-062216a47f38',
#      'predicted_class': 'AI1',
#      'distance': 0.9714120626449585,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112441.jpg'},
#     {'id': 'AI1_6f5786af-524c-4446-a8c4-65b8cb03a859',
#      'predicted_class': 'AI1',
#      'distance': 0.9662814140319824,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112441(1).jpg'},
#     {'id': 'AI1_4f9e8075-0362-43e2-b2ac-058942610245',
#      'predicted_class': 'AI1',
#      'distance': 0.9615927338600159,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112442(0).jpg'},
#     {'id': 'AI1_0b52b876-b4aa-4eb4-b559-39f7d50c6ebe',
#      'predicted_class': 'AI1',
#      'distance': 0.9517076015472412,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112442.jpg'},
#     {'id': 'AI1_cb20c678-49a0-45c1-93ad-fa21d79e92df',
#      'predicted_class': 'AI1',
#      'distance': 0.9425027966499329,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112303.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112333.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_81db9ca2-39e1-459a-8a71-d3fb42c0a78c',
#      'predicted_class': 'AI1',
#      'distance': 0.9715052843093872,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112333(0).jpg'},
#     {'id': 'AI1_79768711-8000-4081-841a-2fd9bd658da0',
#      'predicted_class': 'AI1',
#      'distance': 0.9619371891021729,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112332(1).jpg'},
#     {'id': 'AI1_7827f991-bd2e-4e12-b86c-6ebf5e7776ce',
#      'predicted_class': 'AI1',
#      'distance': 0.9537771940231323,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112335.jpg'},
#     {'id': 'AI1_2ca89edc-a440-4cfa-8bbe-454c66027ff3',
#      'predicted_class': 'AI1',
#      'distance': 0.9504132866859436,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112355.jpg'},
#     {'id': 'AI1_2e4e09c5-41b9-47eb-913b-fd9e8eaf7ae5',
#      'predicted_class': 'AI1',
#      'distance': 0.9500298500061035,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(2).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112327.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_f3b3e198-921a-4e41-8acc-323e621d92b5',
#      'predicted_class': 'AI1',
#      'distance': 0.9734145402908325,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112326(1).jpg'},
#     {'id': 'AI1_2180b391-5d9f-4419-a489-39db2a68cfb3',
#      'predicted_class': 'AI1',
#      'distance': 0.9535810947418213,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112326.jpg'},
#     {'id': 'AI1_09865e88-8e36-443b-bf4a-5a20f23b8e3e',
#      'predicted_class': 'AI1',
#      'distance': 0.9504997730255127,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112325.jpg'},
#     {'id': 'AI1_71904ea0-abeb-4307-973f-6c1162ca9d6e',
#      'predicted_class': 'AI1',
#      'distance': 0.9500472545623779,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112326(0).jpg'},
#     {'id': 'AI1_cb20c678-49a0-45c1-93ad-fa21d79e92df',
#      'predicted_class': 'AI1',
#      'distance': 0.9498502612113953,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112303.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112420(2).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_719701c5-533a-47ae-89ad-93229d6f7396',
#      'predicted_class': 'AI1',
#      'distance': 0.9832054376602173,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(3).jpg'},
#     {'id': 'AI1_de9c2bb9-425f-4b03-a98d-ac191c7ccd05',
#      'predicted_class': 'AI1',
#      'distance': 0.9690300226211548,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(0).jpg'},
#     {'id': 'AI1_87ec4b7f-8562-4488-96e2-ec5bec06f574',
#      'predicted_class': 'AI1',
#      'distance': 0.9681550860404968,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(1).jpg'},
#     {'id': 'AI1_070fa949-3c19-44df-a309-1e613ad3ff1b',
#      'predicted_class': 'AI1',
#      'distance': 0.9676820039749146,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(2).jpg'},
#     {'id': 'AI1_2c0cdd1a-e7d0-4321-8ca5-ab683346b327',
#      'predicted_class': 'AI1',
#      'distance': 0.9662906527519226,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(1).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112432(2).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_8403bedb-60e8-42b8-a4b6-8e2cfbf2db3a',
#      'predicted_class': 'AI1',
#      'distance': 0.9830871820449829,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112433.jpg'},
#     {'id': 'AI1_f2d7b230-5c4a-414c-bdbd-7785073390ee',
#      'predicted_class': 'AI1',
#      'distance': 0.9771793484687805,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112432(0).jpg'},
#     {'id': 'AI1_a7381f8b-836f-4344-a6fa-e70780529707',
#      'predicted_class': 'AI1',
#      'distance': 0.9683431386947632,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112433(0).jpg'},
#     {'id': 'AI1_6c16c962-a8b6-4e0d-bf6c-5f689d1b8457',
#      'predicted_class': 'AI1',
#      'distance': 0.9586838483810425,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112431.jpg'},
#     {'id': 'AI1_8caf9f61-bd87-42ec-a250-6a176a8d1091',
#      'predicted_class': 'AI1',
#      'distance': 0.9573895931243896,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112431(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112319(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_b098b2e8-ec8e-4bed-8dbb-269816fb9507',
#      'predicted_class': 'AI1',
#      'distance': 0.9740778803825378,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112319.jpg'},
#     {'id': 'AI1_2248a805-d6e8-424a-aee3-69d74e49cf97',
#      'predicted_class': 'AI1',
#      'distance': 0.9634557962417603,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112318.jpg'},
#     {'id': 'AI1_589edcf8-e820-45c1-a13b-787315e93eb5',
#      'predicted_class': 'AI1',
#      'distance': 0.9471774697303772,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112314.jpg'},
#     {'id': 'AI1_6f5786af-524c-4446-a8c4-65b8cb03a859',
#      'predicted_class': 'AI1',
#      'distance': 0.9397037029266357,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112441(1).jpg'},
#     {'id': 'AI1_e96888b8-3ac6-4400-a584-062216a47f38',
#      'predicted_class': 'AI1',
#      'distance': 0.9372223019599915,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112441.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112350(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_cff315aa-fa38-48e1-b819-59b17a43f4f1',
#      'predicted_class': 'AI1',
#      'distance': 0.9632267951965332,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112350(1).jpg'},
#     {'id': 'AI1_2ca89edc-a440-4cfa-8bbe-454c66027ff3',
#      'predicted_class': 'AI1',
#      'distance': 0.938518762588501,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112355.jpg'},
#     {'id': 'AI1_1c127333-aff0-40b3-9388-dc8cc6e87750',
#      'predicted_class': 'AI1',
#      'distance': 0.9329067468643188,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112356.jpg'},
#     {'id': 'AI1_ebe43d3a-6fd1-466b-aef8-2eaf6ea700d7',
#      'predicted_class': 'AI1',
#      'distance': 0.9243125319480896,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112356(0).jpg'},
#     {'id': 'AI1_68a7ae66-713a-4b47-a444-52dffc52cfb9',
#      'predicted_class': 'AI1',
#      'distance': 0.9231663346290588,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112351(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112310.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_f0138409-4d12-4fb6-8d4b-3f11f27aa598',
#      'predicted_class': 'AI1',
#      'distance': 0.9829803705215454,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112310(0).jpg'},
#     {'id': 'AI1_2b2365a6-f8aa-46eb-b275-590560d6bcc0',
#      'predicted_class': 'AI1',
#      'distance': 0.9752466082572937,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112310(2).jpg'},
#     {'id': 'AI1_2bdc4190-6725-4a77-905a-7d42def700b8',
#      'predicted_class': 'AI1',
#      'distance': 0.9748963713645935,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112310(1).jpg'},
#     {'id': 'AI1_9e194afe-2eac-49b2-a763-811df46a1735',
#      'predicted_class': 'AI1',
#      'distance': 0.9662487506866455,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112311(1).jpg'},
#     {'id': 'AI1_a03a1097-66f9-4d7c-ab46-bbe7990acded',
#      'predicted_class': 'AI1',
#      'distance': 0.9660691022872925,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112309(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112419(1).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_a1487fbc-987f-4b22-80aa-7d8d3fc6f526',
#      'predicted_class': 'AI1',
#      'distance': 0.9791826009750366,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420.jpg'},
#     {'id': 'AI1_de9c2bb9-425f-4b03-a98d-ac191c7ccd05',
#      'predicted_class': 'AI1',
#      'distance': 0.9668647646903992,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(0).jpg'},
#     {'id': 'AI1_87ec4b7f-8562-4488-96e2-ec5bec06f574',
#      'predicted_class': 'AI1',
#      'distance': 0.9634981155395508,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(1).jpg'},
#     {'id': 'AI1_0a4bfafc-6680-4a5f-b8c4-5e1edfc98aa3',
#      'predicted_class': 'AI1',
#      'distance': 0.9626791477203369,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112423(2).jpg'},
#     {'id': 'AI1_ffad92e0-2bd6-4ae2-9079-d1f588d2e88d',
#      'predicted_class': 'AI1',
#      'distance': 0.9614356756210327,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112419(3).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112405(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_c5112034-dc69-41d7-89fc-e708699a8bd0',
#      'predicted_class': 'AI1',
#      'distance': 0.9587914943695068,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112405.jpg'},
#     {'id': 'AI1_c477ad9c-5809-4b7f-88b9-6a77013e217a',
#      'predicted_class': 'AI1',
#      'distance': 0.9519658088684082,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112404.jpg'},
#     {'id': 'AI1_c1662308-1076-45e0-9c7e-933dd802ba24',
#      'predicted_class': 'AI1',
#      'distance': 0.9282919764518738,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112401(0).jpg'},
#     {'id': 'AI1_48536121-e4b0-40ba-90e9-6e7e6feda8f1',
#      'predicted_class': 'AI1',
#      'distance': 0.9133377075195312,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(1).jpg'},
#     {'id': 'AI1_58ac5f0f-b076-47bb-9c68-b001f7d2c6f8',
#      'predicted_class': 'AI1',
#      'distance': 0.9107087254524231,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(0).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112400.jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_dea2f83b-383f-4bde-9823-5869d496ecb5',
#      'predicted_class': 'AI1',
#      'distance': 0.964824378490448,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112401.jpg'},
#     {'id': 'AI1_c1662308-1076-45e0-9c7e-933dd802ba24',
#      'predicted_class': 'AI1',
#      'distance': 0.9074668288230896,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112401(0).jpg'},
#     {'id': 'AI1_c5112034-dc69-41d7-89fc-e708699a8bd0',
#      'predicted_class': 'AI1',
#      'distance': 0.8960828185081482,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112405.jpg'},
#     {'id': 'AI1_c477ad9c-5809-4b7f-88b9-6a77013e217a',
#      'predicted_class': 'AI1',
#      'distance': 0.8948715925216675,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112404.jpg'},
#     {'id': 'AI1_48536121-e4b0-40ba-90e9-6e7e6feda8f1',
#      'predicted_class': 'AI1',
#      'distance': 0.8679152727127075,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112331(1).jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112419(0).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_40b23d3f-0291-4c13-903a-4d6a54f9faf7',
#      'predicted_class': 'AI1',
#      'distance': 0.9812010526657104,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(2).jpg'},
#     {'id': 'AI1_bcdd9de5-77f4-480e-8f39-7cd89696f3dc',
#      'predicted_class': 'AI1',
#      'distance': 0.9747769832611084,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(0).jpg'},
#     {'id': 'AI1_57a082f0-c414-4081-8243-ab0d75f36986',
#      'predicted_class': 'AI1',
#      'distance': 0.9706069827079773,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112418(1).jpg'},
#     {'id': 'AI1_a1487fbc-987f-4b22-80aa-7d8d3fc6f526',
#      'predicted_class': 'AI1',
#      'distance': 0.9686625003814697,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420.jpg'},
#     {'id': 'AI1_57b413ea-4ded-44f5-bdf7-ec079491b167',
#      'predicted_class': 'AI1',
#      'distance': 0.9568009376525879,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112417.jpg'}]},
#   {'query_image': 'dataset/equipment_test/AI1/20251112_112421(1).jpg',
#    'true_class': 'AI1',
#    'predicted_classes': ['AI1', 'AI1', 'AI1', 'AI1', 'AI1'],
#    'top1_correct': True,
#    'topk_correct': True,
#    'neighbors': [{'id': 'AI1_06b006d0-4e9b-4e40-bb18-13526edbd743',
#      'predicted_class': 'AI1',
#      'distance': 0.9775140285491943,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112421(0).jpg'},
#     {'id': 'AI1_4a48899a-9ece-4c59-b8fd-4175b273d037',
#      'predicted_class': 'AI1',
#      'distance': 0.9751877784729004,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112421.jpg'},
#     {'id': 'AI1_719701c5-533a-47ae-89ad-93229d6f7396',
#      'predicted_class': 'AI1',
#      'distance': 0.9684675931930542,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112420(3).jpg'},
#     {'id': 'AI1_070fa949-3c19-44df-a309-1e613ad3ff1b',
#      'predicted_class': 'AI1',
#      'distance': 0.9618319272994995,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(2).jpg'},
#     {'id': 'AI1_2c0cdd1a-e7d0-4321-8ca5-ab683346b327',
#      'predicted_class': 'AI1',
#      'distance': 0.9501284956932068,
#      'original_path': 'dataset/equipment_train/AI1/20251112_112422(1).jpg'}]}]}
